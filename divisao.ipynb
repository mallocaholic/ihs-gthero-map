# %% [markdown]
# #### Guitar Hero:
#
# - [] Menu
# - [] Procurar assets
# - [] 1 música
# - [] mudar o switch = select
# - [] errar uma nota = led vermelho pisca
#
#
# https://github.com/ellencoutinho/Guitar-Hero
